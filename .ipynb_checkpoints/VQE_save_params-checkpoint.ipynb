# %%
import numpy as np
import numpy.linalg as alg
import matplotlib.pyplot as plt
from qiskit.opflow import X,Z,I, StateFn, CircuitStateFn
from qiskit.providers.aer import QasmSimulator  
from qiskit.providers.aer import StatevectorSimulator, AerSimulator
from qiskit.algorithms import VQE
from qiskit.algorithms.optimizers import COBYLA, SLSQP, SPSA
from qiskit.circuit.library import EfficientSU2, TwoLocal
from qiskit.circuit import QuantumCircuit
from qiskit.execute_function import execute
from qiskit.quantum_info import Statevector

# %%
def NKron(N,op1,op2,pos): 
    '''
    Tensor product operator 
    returns tensor product of op1,op2 on sites pos,pos+1 and identity on remaining sites

    N:number of sites
    op1,op2: Pauli operators on neighboring sites
    pos: site to insert op1
    
    '''
    ide=np.eye(2)
    temp=np.array([ide]*(N),dtype=np.complex128)
    temp[pos,:,:]=op1 
    if pos!=(N-1):
        temp[pos+1,:,:]=op2
    mat=1
    for j in range(N):
        mat=np.kron(mat,temp[j])
    return mat

def QNKron(N,op1,op2,pos): 
    '''
    Tensor product operator (Qiskit Pauli operators)
    returns tensor product of op1,op2 on sites pos,pos+1 and identity on remaining sites

    N:number of sites
    op1,op2: Pauli operators on neighboring sites
    pos: site to insert op1
    '''
    temp=np.array([I]*(N))
    temp[pos]=op1 
    if pos!=(N-1):
        temp[pos+1]=op2
    mat=1
    for j in range(N):
        mat=mat^temp[j]
    return mat

def HIsing(N,lam,p):
    '''
    Quantum Ising Hamiltonian (1D) with transverse field
    
    N:number of sites 
    lam: transverse field)
    '''
    sx=np.array([[0,1],[1,0]])
    sz=np.array([[1,0],[0,-1]])
    ide=np.eye(2)
    H=np.zeros((2**N,2**N))
    for i in range(N-1):
        H=H-NKron(N,sz,sz,i)-lam*NKron(N,sx,ide,i)-p*NKron(N,sz,ide,i)
    H=H-lam*NKron(N,sx,ide,N-1)-p*NKron(N,sz,ide,N-1)
    return H

def QHIsing(N,lam,p):
    '''
    Quantum Ising Hamiltonian (1D) with transverse field (Qiskit Pauli operators)
    
    N:number of sites 
    lam: transverse field)
    '''

    H=-QNKron(N,Z,Z,0)-lam*QNKron(N,X,I,0)-p*QNKron(N,Z,I,0)
    for i in range(1,N-1):
        H=H-QNKron(N,Z,Z,i)-lam*QNKron(N,X,I,i)-p*QNKron(N,Z,I,i)
    H=H-lam*QNKron(N,X,I,N-1)-p*QNKron(N,Z,I,N-1)
    return H

def Mag(N):
    sz=np.array([[1,0],[0,-1]])
    M=np.zeros((2**N,2**N))
    for i in range(N):
        M=M+NKron(N,sz,np.eye(2),i)
    return M/N

# %% [markdown]
# # Run simulation for N=6 and save the parameters of the VQE

# %%
N=5 #number of sites
p=0.00005 #chemical potential to lift the degeneracy

lams=np.logspace(-2,2,10)

backend= StatevectorSimulator()
optimizer = SLSQP(maxiter=1000)
ansatz = EfficientSU2(N, reps=3)
display(ansatz.draw(fold=100))

#backend= AerSimulator() 
#optimizer = SPSA(maxiter=1000)
#ansatz = EfficientSU2(N, reps=1)
#display(ansatz.draw(fold=100))

vqe = VQE(ansatz, optimizer, quantum_instance=backend) 

en=np.zeros(len(lams)); Qen=np.zeros(len(lams)) #arrays of energies
mags=np.zeros(len(lams)); Qmags=np.zeros(len(lams)) #arrays of magnetizations

parameters_ansatz = dict()

for j,lam in enumerate(lams):
    
    print('lambda: %.2f' %lam)
    
    ham=HIsing(N,lam,p) #Numpy Hamiltonian
    Qham=QHIsing(N,lam,p) #Qiskit Hamiltonian
    
    vals,vecs=alg.eigh(ham) #ED with Numpy
    en[j]=vals[0]
    vecs = vecs.T
    result = vqe.compute_minimum_eigenvalue(Qham) #ED with Qiskit VQE
    Qen[j]=result.eigenvalue
    
    mags[j]=vecs[0].T.conj()@Mag(N)@vecs[0] #Magnetization with Numpy results
    Qmags[j]=np.array(result.eigenstate).T.conj()@Mag(N)@np.array(result.eigenstate) #Magnetization with Qiskit results
    #Qmags[j]=np.array(list(result.eigenstate.values())).T.conj()@Mag(N)@np.array(list(result.eigenstate.values())) #Magnetization with Qiskit results
    
    parameters_ansatz[str(lam)] = result.optimal_parameters
    
np.save('params_VQE_ising_N%.0f.npy' %N, parameters_ansatz)
# Out:
#      ┌──────────┐┌──────────┐                         ┌───────────┐┌───────────┐             »
# q_0: ┤ RY(θ[0]) ├┤ RZ(θ[5]) ├──■────■────■─────────■──┤ RY(θ[10]) ├┤ RZ(θ[15]) ├─────────────»
#      ├──────────┤├──────────┤┌─┴─┐  │    │         │  └───────────┘└───────────┘┌───────────┐»
# q_1: ┤ RY(θ[1]) ├┤ RZ(θ[6]) ├┤ X ├──┼────┼────■────┼────────■────────────■──────┤ RY(θ[11]) ├»
#      ├──────────┤├──────────┤└───┘┌─┴─┐  │  ┌─┴─┐  │        │            │      └───────────┘»
# q_2: ┤ RY(θ[2]) ├┤ RZ(θ[7]) ├─────┤ X ├──┼──┤ X ├──┼────────┼────────────┼────────────■──────»
#      ├──────────┤├──────────┤     └───┘┌─┴─┐└───┘  │      ┌─┴─┐          │          ┌─┴─┐    »
# q_3: ┤ RY(θ[3]) ├┤ RZ(θ[8]) ├──────────┤ X ├───────┼──────┤ X ├──────────┼──────────┤ X ├────»
#      ├──────────┤├──────────┤          └───┘     ┌─┴─┐    └───┘        ┌─┴─┐        └───┘    »
# q_4: ┤ RY(θ[4]) ├┤ RZ(θ[9]) ├────────────────────┤ X ├─────────────────┤ X ├─────────────────»
#      └──────────┘└──────────┘                    └───┘                 └───┘                 »
# «                                                                        ┌───────────┐┌───────────┐»
# «q_0: ───────────────────■─────────────────────────■────────■─────────■──┤ RY(θ[20]) ├┤ RZ(θ[25]) ├»
# «     ┌───────────┐    ┌─┴─┐                       │        │         │  └───────────┘└───────────┘»
# «q_1: ┤ RZ(θ[16]) ├────┤ X ├───────────────────────┼────────┼────■────┼────────■────────────■──────»
# «     └───────────┘┌───┴───┴───┐┌───────────┐    ┌─┴─┐      │  ┌─┴─┐  │        │            │      »
# «q_2: ──────■──────┤ RY(θ[12]) ├┤ RZ(θ[17]) ├────┤ X ├──────┼──┤ X ├──┼────────┼────────────┼──────»
# «           │      └───────────┘├───────────┤┌───┴───┴───┐┌─┴─┐└───┘  │      ┌─┴─┐          │      »
# «q_3: ──────┼────────────■──────┤ RY(θ[13]) ├┤ RZ(θ[18]) ├┤ X ├───────┼──────┤ X ├──────────┼──────»
# «         ┌─┴─┐        ┌─┴─┐    ├───────────┤├───────────┤└───┘     ┌─┴─┐    └───┘        ┌─┴─┐    »
# «q_4: ────┤ X ├────────┤ X ├────┤ RY(θ[14]) ├┤ RZ(θ[19]) ├──────────┤ X ├─────────────────┤ X ├────»
# «         └───┘        └───┘    └───────────┘└───────────┘          └───┘                 └───┘    »
# «                                                                                     ┌───────────┐»
# «q_0: ────────────────────────────────■─────────────────────────■────────■─────────■──┤ RY(θ[30]) ├»
# «     ┌───────────┐┌───────────┐    ┌─┴─┐                       │        │         │  └───────────┘»
# «q_1: ┤ RY(θ[21]) ├┤ RZ(θ[26]) ├────┤ X ├───────────────────────┼────────┼────■────┼────────■──────»
# «     └───────────┘└───────────┘┌───┴───┴───┐┌───────────┐    ┌─┴─┐      │  ┌─┴─┐  │        │      »
# «q_2: ──────■────────────■──────┤ RY(θ[22]) ├┤ RZ(θ[27]) ├────┤ X ├──────┼──┤ X ├──┼────────┼──────»
# «         ┌─┴─┐          │      └───────────┘├───────────┤┌───┴───┴───┐┌─┴─┐└───┘  │      ┌─┴─┐    »
# «q_3: ────┤ X ├──────────┼────────────■──────┤ RY(θ[23]) ├┤ RZ(θ[28]) ├┤ X ├───────┼──────┤ X ├────»
# «         └───┘        ┌─┴─┐        ┌─┴─┐    ├───────────┤├───────────┤└───┘     ┌─┴─┐    └───┘    »
# «q_4: ─────────────────┤ X ├────────┤ X ├────┤ RY(θ[24]) ├┤ RZ(θ[29]) ├──────────┤ X ├─────────────»
# «                      └───┘        └───┘    └───────────┘└───────────┘          └───┘             »
# «     ┌───────────┐
# «q_0: ┤ RZ(θ[35]) ├─────────────────────────────────────────────────────────────────
# «     └───────────┘┌───────────┐┌───────────┐
# «q_1: ──────■──────┤ RY(θ[31]) ├┤ RZ(θ[36]) ├───────────────────────────────────────
# «           │      └───────────┘└───────────┘┌───────────┐┌───────────┐
# «q_2: ──────┼────────────■────────────■──────┤ RY(θ[32]) ├┤ RZ(θ[37]) ├─────────────
# «           │          ┌─┴─┐          │      └───────────┘├───────────┤┌───────────┐
# «q_3: ──────┼──────────┤ X ├──────────┼────────────■──────┤ RY(θ[33]) ├┤ RZ(θ[38]) ├
# «         ┌─┴─┐        └───┘        ┌─┴─┐        ┌─┴─┐    ├───────────┤├───────────┤
# «q_4: ────┤ X ├─────────────────────┤ X ├────────┤ X ├────┤ RY(θ[34]) ├┤ RZ(θ[39]) ├
# «         └───┘                     └───┘        └───┘    └───────────┘└───────────┘
# lambda: 0.01
# /home/joana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/joana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: ComplexWarning: Casting complex values to real discards the imaginary part
# lambda: 0.03
# lambda: 0.08
# lambda: 0.22
# lambda: 0.60
# lambda: 1.67
# lambda: 4.64
# lambda: 12.92
# lambda: 35.94
# lambda: 100.00

# %% [markdown]
# # Use the saved parameters to define unitary transformation

# %%
N = 5 #number of sites
p=0.00005 #chemical potential to lift the degeneracy

VQE_vals = np.load(f'params_VQE_ising_N{N}.npy', allow_pickle=True).item()

backend= StatevectorSimulator()
lams_str = np.array([_ for _ in VQE_vals]) # list of lambda values (the items in the dictionary)
lams = np.logspace(-2,2,10)

SQen=np.zeros(len(lams))
SQmags=np.zeros(len(lams))

for j in range(len(lams)):
    
    Qham = QHIsing(N,lams[j],p) #Qiskit Hamiltonian
    
    vals = VQE_vals[lams_str[j]]
    indices = np.array([_.index for _ in vals]) # unordered list of indices from the ParameterVectorElement(Theta(INDEX))
    vals_sorted = [vals[_] for _ in vals] # unordered list of values (but same ordering as indices)
    sorter = np.argsort(indices)
    vals_sorted = np.array(vals_sorted)[sorter]

    ansatz = EfficientSU2(N, reps=3)
    ansatz = ansatz.assign_parameters(vals_sorted)
    
    qc = QuantumCircuit(N)  
    qc.compose(ansatz, inplace=True)
    
    SQen[j] = Statevector(qc).expectation_value(Qham)
    SQmags[j] = Statevector(qc).expectation_value(Mag(N))
    
    #exp_E = ~StateFn(Qham) @ CircuitStateFn(primitive=qc, coeff=1.)
    #exp_M = ~StateFn(Mag(N)) @ CircuitStateFn(primitive=qc, coeff=1.)
# Out:
# /home/joana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/joana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: ComplexWarning: Casting complex values to real discards the imaginary part

# %% [markdown]
# ## Plot resulting energies and magnetization

# %%
plt.figure(dpi=220)
plt.plot(lams,en,'o-', alpha=0.5)
plt.plot(lams,Qen, 'd:', alpha=0.5)
plt.plot(lams,SQen, '*:', alpha=0.5)
plt.legend(["Numpy","Qiskit VQE","Qiskit Ansatz"])
plt.xscale("log")
plt.xlabel("Magnetic field")
plt.ylabel("Energies")

plt.figure(dpi=200)
plt.plot(lams,abs(mags),'o-', alpha=0.5)
plt.plot(lams,abs(Qmags), 'd:', alpha=0.5)
plt.plot(lams,abs(SQmags), '*:', alpha=0.5)
plt.legend(["Numpy","Qiskit VQE","Qiskit Ansatz"])
plt.xscale("log")
plt.xlabel("Magnetic field")
plt.ylabel("Magnetization")
# Out:
# Text(0, 0.5, 'Magnetization')
